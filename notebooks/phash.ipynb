# %%
from PIL import Image
import imagehash
from pathlib import Path
from matplotlib.pyplot import imshow, figure
import numpy as np
imgs = list(Path(r'C:\Users\tdams\OneDrive\Documents\trashcam_images\20161118\08').glob('**/*.jpg'))
# %matplotlib inline
from collections import deque

# %%
crop = (600,430,900,600)
hash_size = 4

img = Image.open(imgs[0],'r')
img = img.crop(crop)
imshow(np.asarray(img))

# %%
for i, img in enumerate(imgs[0:100]):
    img = Image.open(img,'r')
    img = img.crop(crop)
    new_hash = imagehash.phash(img,hash_size=hash_size).hash.flatten()
# Out:
# 0 eb24
# 18 6ba4
# 19 eb24
# 21 cb64
# 22 6b64
# 23 eb24
# 36 436e
# 37 cb26
# 38 eb24
# 49 6b26
# 50 eb24
# 51 b546
# 52 eb24

# %%
from scipy.spatial.distance import hamming

hash_size = 4
for i, img in enumerate(imgs[0:100]):
    img = Image.open(img,'r')
    img = img.crop((500,430,1200,600))
    new_hash = imagehash.phash(img,hash_size=4).hash.flatten()
    print(int(hamming(old_hash,new_hash)*16))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fbae2d612829> in <module>()
# ----> 1 old_hash = np.True_(16)
#       2 from scipy.spatial.distance import hamming
#       3
#       4 hash_size = 4
#       5 for i, img in enumerate(imgs[0:100]):
#
# TypeError: 'numpy.bool_' object is not callable

# %%
old_hash = np.true_divide(16)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-2f38f27dff16> in <module>()
# ----> 1 old_hash = np.true_divide(16)
#
# ValueError: invalid number of arguments

# %%
new_hash
# Out:
# array([ True,  True, False, False, False, False,  True,  True,  True,
#        False, False,  True, False,  True,  True, False], dtype=bool)

# %%
import binascii

# %%
scale = 16 ## equals to hexadecimal

num_of_bits = 8

bin(int(new_hash, scale))[2:].zfill(num_of_bits)
# Out:
# '1100001101101001'

# %%
# Out:
# BitArray('0xc369')

# %%
BitArray('0xc369')
# Out:
# BitArray('0xc369')

# %%
from scipy.spatial.distance import hamming

# %%
hamming_weight(bin(66),bin(67))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-18168f251931> in <module>()
# ----> 1 hamming_weight(bin(66),bin(67))
#
# <ipython-input-8-7a0728983fad> in hamming_weight(a, b)
#       1 def hamming_weight(a, b):
# ----> 2     return (a^b).count(True)
#
# TypeError: unsupported operand type(s) for ^: 'str' and 'str'

# %%
bin(4)
# Out:
# '0b100'

# %%
from bitstring import BitArray

# %%
BitArray(bin(12))
# Out:
# BitArray('0xc')

# %%
def hamming_weight(a, b):
    return (a^b).count(True)

# %%
hamming_weight(BitArray(bin(66)),BitArray(bin(74)))
# Out:
# 1
